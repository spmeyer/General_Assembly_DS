# %%
# PART I: Read in the file with csv.reader() and store it in an object called 'file_nested_list'.

# %%
fileneam = 'chipotle.tsv'

# %%
cd /Users/spmeyer/DAT-DC-10/data
# Out:
# /Users/spmeyer/DAT-DC-10/data

# %%
import csv

# %%
with open(filename, mode='rU') as f:
    file_nested_list = [row for row in csv.reader(f, delimiter='\t')]

# %%
file_nested_list
# Out:
# [['order_id', 'quantity', 'item_name', 'choice_description', 'item_price'],
#  ['1', '1', 'Chips and Fresh Tomato Salsa', 'NULL', '$2.39 '],
#  ['1', '1', 'Izze', '[Clementine]', '$3.39 '],
#  ['1', '1', 'Nantucket Nectar', '[Apple]', '$3.39 '],
#  ['1', '1', 'Chips and Tomatillo-Green Chili Salsa', 'NULL', '$2.39 '],
#  ['2',
#   '2',
#   'Chicken Bowl',
#   '[Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]',
#   '$16.98 '],
#  ['3',
#   '1',
#   'Chicken Bowl',
#   '[Fresh Tomato Salsa (Mild), [Rice, Cheese, Sour Cream, Guacamole, Lettuce]]',
#   '$10.98 '],
#  ['3', '1', 'Side of Chips', 'NULL', '$1.69 '],
#  ['4',
#   '1',
#   'Steak Burrito',
#   '[Tomatillo Red Chili Salsa, [Fajita Vegetables, Black Beans, Pinto Beans, Cheese, Sour Cream, Guacamole, Lettuce]]',
#   '$11.75 '],
#  ['4',
#   '1',
#   'Steak Soft Tacos',
#   '[Tomatillo Green Chili Salsa, [Pinto Beans, Cheese, Sour Cream, Lettuce]]',
#   '$9.25 '],
#  ['5',
#   '1',
#   'Steak Burrito',
# ...

# %%
# PART 2: Separate 'file_nested_list' into the 'header' and the 'data'.

# %%
header = file_nested_list[0]

# %%
header
# Out:
# ['order_id', 'quantity', 'item_name', 'choice_description', 'item_price']

# %%
data = file_nested_list[1:]

# %%
data[1:6]
# Out:
# [['1', '1', 'Izze', '[Clementine]', '$3.39 '],
#  ['1', '1', 'Nantucket Nectar', '[Apple]', '$3.39 '],
#  ['1', '1', 'Chips and Tomatillo-Green Chili Salsa', 'NULL', '$2.39 '],
#  ['2',
#   '2',
#   'Chicken Bowl',
#   '[Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]',
#   '$16.98 '],
#  ['3',
#   '1',
#   'Chicken Bowl',
#   '[Fresh Tomato Salsa (Mild), [Rice, Cheese, Sour Cream, Guacamole, Lettuce]]',
#   '$10.98 ']]

# %% [markdown]
# data[-5:-1]

# %%
# PART 3: Calculate the average price of an order.
# Hint: Examine the data to see if the 'quantity' column is relevant to this calculation.
# Hint: Think carefully about the simplest way to do this!

# %%
# Quantity is in column [1].  Is it relevant to this calculution?  Let's see...
# After exploring, saw that, for example, 'Canned Soda' demonstrated that quantity was reflected in item price.  
# So it really isn't single item price, but rather quantity * items price.  Badly named variable.

# %%
# So, to get average price of an order we need only the sum of each lines' price / number of orders.

# %%
# First, let's get the sum of prices, the last item in each row.

# %%
prices = [row[-1] for row in data]

# %%
prices[:5]
# Out:
# ['$2.39 ', '$3.39 ', '$3.39 ', '$2.39 ', '$16.98 ']

# %%
# prices as strings, but need to get rid of $ sign and turn them into floats... let's try again.
# first, let's try to get rid of the '$'.

# %%
prices = [row[-1].replace('$','') for row in data]

# %%
prices[:5]
# Out:
# ['2.39 ', '3.39 ', '3.39 ', '2.39 ', '16.98 ']

# %%
# OK, we got rid of the $, now to turn the number from string into a float.

# %%
prices = [float(row[-1].replace('$','')) for row in data]

# %%
prices[:5]
# Out:
# [2.39, 3.39, 3.39, 2.39, 16.98]

# %%
# OK, now let's sum up the prices to get total prices

# %%
total_price = sum(price for price in prices)

# %%
total_price
# Out:
# 34500.16000000046

# %%
# And the total number of order is from order id... this data run is order from first order ID to last order id.

# %%
total_orders = float(data[-1][0])

# %%
total_orders
# Out:
# 1834.0

# %%
# Avg order price = total price / total orders...

# %%
avg_price = total_price / total_orders

# %%
avg_price
# Out:
# 18.811428571428824

# %%
# PART 4: Create a list (or set) of all unique sodas and soft drinks that they sell.
# Note: Just look for 'Canned Soda' and 'Canned Soft Drink', and ignore other drinks like 'Izze'.

# %%
# Oh, heck, what does our data look like?  Let's see again...

# %%
header
# Out:
# ['order_id', 'quantity', 'item_name', 'choice_description', 'item_price']

# %%
data[15:20]
# Out:
# [['8', '1', 'Chips and Tomatillo-Green Chili Salsa', 'NULL', '$2.39 '],
#  ['8',
#   '1',
#   'Chicken Burrito',
#   '[Tomatillo-Green Chili Salsa (Medium), [Pinto Beans, Cheese, Sour Cream]]',
#   '$8.49 '],
#  ['9',
#   '1',
#   'Chicken Burrito',
#   '[Fresh Tomato Salsa (Mild), [Black Beans, Rice, Cheese, Sour Cream, Lettuce]]',
#   '$8.49 '],
#  ['9', '2', 'Canned Soda', '[Sprite]', '$2.18 '],
#  ['10',
#   '1',
#   'Chicken Bowl',
#   '[Tomatillo Red Chili Salsa, [Fajita Vegetables, Black Beans, Sour Cream, Cheese, Lettuce]]',
#   '$8.75 ']]

# %%
# So, we want to find 'Canned Soda' or 'Canned Soft Drink' in row column [2] in data, and then unique 'choice descriptions in row column [3]

# %%
# use a for loop to get a list of all the sodas
sodas = []
for row in data:
    if 'Canned' in row[2]:
        sodas.append(row[3][1:-1])      
        # strip the brackets

# %%
sodas
# Out:
# ['Sprite',
#  'Dr. Pepper',
#  'Mountain Dew',
#  'Sprite',
#  'Dr. Pepper',
#  'Diet Dr. Pepper',
#  'Coca Cola',
#  'Diet Coke',
#  'Diet Dr. Pepper',
#  'Coca Cola',
#  'Dr. Pepper',
#  'Coca Cola',
#  'Diet Coke',
#  'Mountain Dew',
#  'Mountain Dew',
#  'Dr. Pepper',
#  'Mountain Dew',
#  'Diet Dr. Pepper',
#  'Mountain Dew',
#  'Coke',
#  'Coca Cola',
#  'Sprite',
#  'Diet Coke',
#  'Coke',
#  'Coke',
#  'Lemonade',
#  'Sprite',
#  'Diet Coke',
#  'Coca Cola',
#  'Diet Coke',
#  'Diet Coke',
#  'Mountain Dew',
#  'Coke',
#  'Coke',
#  'Coke',
#  'Sprite',
#  'Coke',
#  'Coke',
#  'Dr. Pepper',
#  'Coca Cola',
#  'Dr. Pepper',
#  'Coke',
#  'Diet Dr. Pepper',
#  'Diet Coke',
#  'Lemonade',
#  'Coke',
#  'Diet Coke',
#  'Diet Coke',
#  'Diet Coke',
#  'Diet Coke',
#  'Nestea',
#  'Diet Coke',
#  'Dr. Pepper',
#  'Coke',
#  'Sprite',
#  'Coke',
#  'Lemonade',
#  'Coke',
#  'Coke',
#  'Diet Coke',
#  'Diet Coke',
#  'Coca Cola',
#  'Coca Cola',
#  'Lemonade',
#  'Lemonade',
# ...

# %%
# for practice, use a list comprehension  to do the same
sodas = [row[3][1:-1] for row in data if 'Canned' in row[2]]

# %%
sodas
# Out:
# ['Sprite',
#  'Dr. Pepper',
#  'Mountain Dew',
#  'Sprite',
#  'Dr. Pepper',
#  'Diet Dr. Pepper',
#  'Coca Cola',
#  'Diet Coke',
#  'Diet Dr. Pepper',
#  'Coca Cola',
#  'Dr. Pepper',
#  'Coca Cola',
#  'Diet Coke',
#  'Mountain Dew',
#  'Mountain Dew',
#  'Dr. Pepper',
#  'Mountain Dew',
#  'Diet Dr. Pepper',
#  'Mountain Dew',
#  'Coke',
#  'Coca Cola',
#  'Sprite',
#  'Diet Coke',
#  'Coke',
#  'Coke',
#  'Lemonade',
#  'Sprite',
#  'Diet Coke',
#  'Coca Cola',
#  'Diet Coke',
#  'Diet Coke',
#  'Mountain Dew',
#  'Coke',
#  'Coke',
#  'Coke',
#  'Sprite',
#  'Coke',
#  'Coke',
#  'Dr. Pepper',
#  'Coca Cola',
#  'Dr. Pepper',
#  'Coke',
#  'Diet Dr. Pepper',
#  'Diet Coke',
#  'Lemonade',
#  'Coke',
#  'Diet Coke',
#  'Diet Coke',
#  'Diet Coke',
#  'Diet Coke',
#  'Nestea',
#  'Diet Coke',
#  'Dr. Pepper',
#  'Coke',
#  'Sprite',
#  'Coke',
#  'Lemonade',
#  'Coke',
#  'Coke',
#  'Diet Coke',
#  'Diet Coke',
#  'Coca Cola',
#  'Coca Cola',
#  'Lemonade',
#  'Lemonade',
# ...

# %%
# now use the set() function to get just the unique elements of the list
unique_sodas = set(sodas)

# %%
unique_sodas
# Out:
# {'Coca Cola',
#  'Coke',
#  'Diet Coke',
#  'Diet Dr. Pepper',
#  'Dr. Pepper',
#  'Lemonade',
#  'Mountain Dew',
#  'Nestea',
#  'Sprite'}

# %%
# PART 5: Calculate the average number of toppings per burrito.
# Note: Let's ignore the 'quantity' column to simplify this task.
# Hint: Think carefully about the easiest way to count the number of toppings!

# %%
# We need to find the rows with burritos (and know how many rows/burritos we have), and then count the number of toppings on those rows with burritos.

# %%
num_burritos = 0.0
num_toppings = 0.0

# %%
for row in data:
    if 'Burrito' in row[2]:
        num_burritos += 1

# %%
num_burritos
# Out:
# 1172.0

# %%
# How figure out number of toppings?  Let's explore...

# %%
test = data[21]

# %%
test
# Out:
# ['11',
#  '1',
#  'Barbacoa Burrito',
#  '[[Fresh Tomato Salsa (Mild), Tomatillo-Green Chili Salsa (Medium), Tomatillo-Red Chili Salsa (Hot)], [Rice, Cheese, Sour Cream, Lettuce]]',
#  '$8.99 ']

# %%
test[3]
# Out:
# '[[Fresh Tomato Salsa (Mild), Tomatillo-Green Chili Salsa (Medium), Tomatillo-Red Chili Salsa (Hot)], [Rice, Cheese, Sour Cream, Lettuce]]'

# %%
test[3].count(',')
# Out:
# 6

# %%
# reset our counters...
num_burritos = 0.0
num_toppings = 0.0

# %%
for row in data:
    if 'Burrito' in row[2]:
        num_burritos += 1
        num_toppings += (row[3].count(',')+1)

# %%
num_burritos
# Out:
# 1172.0

# %%
num_toppings
# Out:
# 6323.0

# %%
avg_tops_per_burrito = round(num_toppings/num_burritos,2)

# %%
'%.2f' % avg_tops_per_burrito
# Out:
# '5.40'

# %%
# PART 6: Create a dictionary in which the keys represent chip orders and
#  the values represent the total number of orders.
# Expected output: {'Chips and Roasted Chili-Corn Salsa': 18, ... }
# Note: Please take the 'quantity' column into account!
# Optional: Learn how to use 'defaultdict' to simplify your code.

# %%
# Recall from "Python for Informatics" Chap 9.1 by Charles Severance at UMichigan
# word = 'brontosaurus'
# d = dict() 
# for c in word:
#    d[c] = d.get(c,0) + 1
#    print d

# %%
data[0:5]
# Out:
# [['1', '1', 'Chips and Fresh Tomato Salsa', 'NULL', '$2.39 '],
#  ['1', '1', 'Izze', '[Clementine]', '$3.39 '],
#  ['1', '1', 'Nantucket Nectar', '[Apple]', '$3.39 '],
#  ['1', '1', 'Chips and Tomatillo-Green Chili Salsa', 'NULL', '$2.39 '],
#  ['2',
#   '2',
#   'Chicken Bowl',
#   '[Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]',
#   '$16.98 ']]

# %%
chip_orders = [row[2] for row in data if "Chip" in row[2]]

# %%
chip_orders[0:5]
# Out:
# ['Chips and Fresh Tomato Salsa',
#  'Chips and Tomatillo-Green Chili Salsa',
#  'Side of Chips',
#  'Chips and Guacamole',
#  'Chips and Guacamole']

# %%
chip_count = dict()

# %%
for chip_type in chip_orders:
    chip_count[chip_type] = chip_count.get(chip_type,0) + 1
print chip_count
# Out:
# {'Chips and Roasted Chili-Corn Salsa': 18, 'Chips and Tomatillo-Red Chili Salsa': 20, 'Chips and Mild Fresh Tomato Salsa': 1, 'Chips and Guacamole': 479, 'Chips and Fresh Tomato Salsa': 110, 'Chips and Tomatillo Red Chili Salsa': 48, 'Chips and Tomatillo-Green Chili Salsa': 31, 'Side of Chips': 101, 'Chips and Roasted Chili Corn Salsa': 22, 'Chips': 211, 'Chips and Tomatillo Green Chili Salsa': 43}

# %%
# let's learn about a new way to do this
# defaultdict saves you the trouble of checking whether a key already exists
from collections import defaultdict
dchips = defaultdict(int)
for row in data:
    if 'Chips' in row[2]:
        dchips[row[2]] += int(row[1])

# %%
print dchips
# Out:
# defaultdict(<type 'int'>, {'Chips and Roasted Chili-Corn Salsa': 18, 'Chips and Tomatillo-Red Chili Salsa': 25, 'Chips and Mild Fresh Tomato Salsa': 1, 'Chips and Guacamole': 506, 'Chips and Fresh Tomato Salsa': 130, 'Chips and Tomatillo Red Chili Salsa': 50, 'Chips and Tomatillo-Green Chili Salsa': 33, 'Side of Chips': 110, 'Chips and Roasted Chili Corn Salsa': 23, 'Chips': 230, 'Chips and Tomatillo Green Chili Salsa': 45})
